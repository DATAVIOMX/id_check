# %%
from PIL import Image
import pytesseract
import cv2
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
image_1 = cv2.imread("ifes/5_front.jpg")

# %%
plt.imshow(image_1)

# %%
text_1 = pytesseract.image_to_string(Image.open("ifes/5_front.jpg"), 'spa')

# %%
text_1
# Out:
# '(AAN L,\nLe\n\n  \n\nE E\nNOMBRE pEoHa\nHr JE 13/01\nCORONA en\n\n \n\nINSTITUTO NACIONAL ELECTORAL\nCREDENCIAL PARA VOTAR\n\n  \n\nJORGE ALFREDO\n\nDOMICILIO\n\nC SOMBRERETE 500\n\nCOL HIPODROMO CONDESA 06170\nCUAUHTEMOG, D.F.\n\nCLAVE ni ELECTOR ARCRUR84011309H400\ncunp AACJ840113HDFRRRO8 AÑO DE REGISTRO 2002 02\nesaoo 09 unio DIS. sección 4567\n\n¿ocaumo 0001 eusón 2010 weon 20% Y,'
